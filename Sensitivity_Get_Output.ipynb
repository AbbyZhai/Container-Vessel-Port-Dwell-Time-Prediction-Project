# %% [markdown]
# ### Sensitivity analysis preparation
#
# The CatBoost modeling notebook found these values to be the best model parameters:
#
# ```
# {'iterations': 1538,
#  'learning_rate': 0.052313318764570016,
#  'depth': 5,
#  'l2_leaf_reg': 0.02252067954779648,
#  'loss_function': 'MAE',
#  'random_seed': 42,
#  'verbose': False}
# ```
#
# In order to check model sensitivity a number of runs with different hyperparameter settings are needed. And all this needs to be 10 kfold cross validate all this! This can be very time consuming and resource intensive.
#
# This notebook is a helper notebook that will do the runs to generate cross validated scores over a range of values preceding and succeeding the best model values, for each of these parameters:
#
# ```
# 'iterations': 1538
# 'learning_rate': 0.052313318764570016
# 'depth': 5
# ```
#
# NOTE: in CatBoost, iterations means the number of trees.
#
# We will hold all other hyperparameters constant at their best model values.
#
# This will take a very long time to run. **Approximately 10 hours in some cases**
#
#
# Because it can take so long it might be prone to crashing or not completing all runs. To avoid data loss we save the data to a text file (json) for parsing and sensitivity analysis in another notebook.

# %%
import pandas as pd 
import numpy as np
from catboost import CatBoostRegressor, Pool, metrics, cv
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

import altair as alt
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime
import json

import warnings
warnings.filterwarnings("ignore")

RANDOM_STATE = 42

# %% [markdown]
# #### Data Preparation

# %%
# Load vessel data
df_vessel = pd.read_csv('./data/cleansed/vessel_dwell_time.csv')

X = df_vessel.drop(columns=[ 'imo', 'vessel_name', 'time_seen', 'vessel_type', 'dwell_in_hr'])
y = df_vessel['dwell_in_hr']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1634 entries, 0 to 1633
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   target_terminal                   1634 non-null   object
#  1   avg_dwell_at_target_terminal      1634 non-null   float64
#  2   num_of_vessel_at_target_terminal  1634 non-null   float64
#  3   num_of_vessel_in_port             1634 non-null   float64
#  4   weekday                           1634 non-null   int64
#  5   hour_of_day                       1634 non-null   int64
#  6   is_holiday                        1634 non-null   bool
#  7   vessel_operator                   1634 non-null   object
#  8   vessel_width                      1634 non-null   float64
#  9   vessel_length                     1634 non-null   float64
#  10  vessel_dwt                        1634 non-null   float64
# dtypes: bool(1), float64(6), int64(2), object(2)
# memory usage: 129.4+ KB

# %%
# create training set and testing set
# CatBoost has built-in support for categorical data. We are not required to handle it seperately
categorical_features_indices = [0,6,7]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

# create data pool for training set. Pool is specific to CatBoost
train_pool = Pool(data=X_train, label=y_train, cat_features=categorical_features_indices)
test_pool = Pool(data=X_test, label=y_test, cat_features=categorical_features_indices)

# %% [markdown]
# ### Best model sanity check

# %% [markdown]
# Here we run a cross validation using the best model parameters we found in the CatBoost modeling phase of the project to reconfirm that best parameters that we should be using to do our sensitivity analysis.

# %%
# %%time
best_model_params = {'iterations': 1538,
 'learning_rate': 0.052313318764570016,
 'depth': 5,
 'l2_leaf_reg': 0.02252067954779648,
 'loss_function': 'MAE',
 'random_seed': 42,
 'verbose': False}

cv_data = cv(
    pool=train_pool,
    params=best_model_params,   #best_model.get_params(), # get params from the best model 
    fold_count=10,
    logging_level='Silent'
)
# Out:
# CPU times: user 1min, sys: 20 s, total: 1min 20s
# Wall time: 33.8 s

# %%
cv_data
# Out:
#       iterations  test-MAE-mean  test-MAE-std  train-MAE-mean  train-MAE-std
# 0              0      92.877398     18.473768       92.891975       2.110095
# 1              1      91.187773     18.402669       91.172426       2.034235
# 2              2      90.092463     18.378381       90.050731       1.964056
# 3              3      89.076065     18.372967       89.024624       1.943006
# 4              4      87.731904     18.356970       87.715147       1.894724
# ...          ...            ...           ...             ...            ...
# 1533        1533      54.321525     11.543025       26.302379       0.861408
# 1534        1534      54.321185     11.543103       26.298282       0.861873
# 1535        1535      54.318501     11.541900       26.292712       0.861953
# 1536        1536      54.317159     11.541449       26.289147       0.861932
# 1537        1537      54.325687     11.532876       26.278719       0.856171
#
# [1538 rows x 5 columns]

# %% [markdown]
# This confirms the best values from before in the CatBoost modeling notebook:
#
# * test-MAE-mean = 54.325687

# %%
cv_data.iloc[-1]
# Out:
# iterations        1537.000000
# test-MAE-mean       54.325687
# test-MAE-std        11.532876
# train-MAE-mean      26.278719
# train-MAE-std        0.856171
# Name: 1537, dtype: float64

# %% [markdown]
# ### Hyperparameter sensitivity

# %% [markdown]
# Now let's iterate over a range of values for the chosen hyperparameters. This will take a very long time since we're doing 10 fold cross validation for each of the combinations of values. It will take around 10 hours.

# %%
'''
Generate a linspace, but one that always crosses over and includes
a specific value as the center element of the linspace. Example:

    mycenter = 5
    x = get_centered_linspace(center = mycenter, 
                              steps = 3,
                              distance = 10,
                              use_int = False)

produces 'x' as follows:

    [0.0, 2.5, 5.0, 7.5, 10.0]

Notice center value is 5.0 (which is 'mycenter').
Notice the distance 'x[-1] - x[0]' is 10. 
Notice 'steps' is 3 steps in each direction from the 'mycenter' (self inclusive)

If use_int = True the result would have been:

    [0, 2, 5, 7, 10]

The length of the list returned is always odd.

'''
def get_centered_linspace(center, steps, distance, use_int):
    half_distance = distance/2
    left = center - half_distance
    right = center + half_distance
    left_segment = list(np.linspace(start=left, stop=center, num=steps, endpoint=True))
    right_segment = list(np.linspace(start=center, stop=right, num=steps))
    '''
    print(left, center, right, half_distance, steps)
    print(left_segment)
    print(right_segment)
    '''

    lin = list(left_segment[:-1] + right_segment)
    if use_int:
        return [int(i) for i in lin]
    return lin


'''
Get a human readable date time PDT to help in debug log data

'''
def get_now_datetime_str():
    return (datetime.datetime.now() - 
            datetime.timedelta(hours=7)).strftime("%Y-%m-%d %H:%M:%S PDT")

'''
Human readable date time PDT for file name

'''
def get_now_datetime_filename_str():
    return (datetime.datetime.now() - 
            datetime.timedelta(hours=7)).strftime("%Y-%m-%d_%H-%M-%S-PDT")

# %% [markdown]
# Set up our ranges to iterate over for each of our hyperparameter. The range will cross over the actual best model value for that hyperparameter. In fact for our tests, the middle value in the range will be the actual best model value for that parameter.

# %%
best_model_params = {'iterations': 1538,
 'learning_rate': 0.052313318764570016,
 'depth': 5,
 'l2_leaf_reg': 0.02252067954779648,
 'loss_function': 'MAE',
 'random_seed': 42,
 'verbose': False}

bmit = best_model_params['iterations']
bmlr = best_model_params['learning_rate']
bmd = best_model_params['depth']

# %%
best_model_params
# Out:
# {'iterations': 1538,
#  'learning_rate': 0.052313318764570016,
#  'depth': 5,
#  'l2_leaf_reg': 0.02252067954779648,
#  'loss_function': 'MAE',
#  'random_seed': 42,
#  'verbose': False}

# %% [markdown]
# ### Example run

# %% [markdown]
# Prep the hyperparameter ranges that we will use for each cross-validation.
#
# NOTE: For our final report we will actually only use 1538 as the iteration to use. Because in our Feature Analysis we found that the two most important features by far were learning_rate and depth.

# %%
# this is the number of trees essentially, notice the center value 1538 is the actual best model value
iteration_range = get_centered_linspace(center=bmit, steps=5, distance=bmit*1, use_int=True)
iteration_range
# Out:
# [769, 961, 1153, 1345, 1538, 1730, 1922, 2114, 2307]

# %%
# notice the center value 0.052313318764570016 is the actual best model value
learning_rate_range = get_centered_linspace(center=bmlr, steps=5, distance=bmlr*1.5, use_int=False)
learning_rate_range
# Out:
# [0.013078329691142504,
#  0.022887076959499382,
#  0.03269582422785626,
#  0.04250457149621314,
#  0.052313318764570016,
#  0.062122066032926894,
#  0.07193081330128377,
#  0.08173956056964066,
#  0.09154830783799753]

# %%
# According to CatBoost documentation https://catboost.ai/en/docs/concepts/parameter-tuning
# "In most cases, the optimal depth ranges from 4 to 10. Values in the range
# from 6 to 10 are recommended." Also note the parameter is an int.
#
# In our case the best model value is actually 5. But since the docs are saying 
# optimal depth are from 4 to 10 anyway, let's just use that as the range.
#
depth_range = [4,5,6,7,8,9,10]
depth_range
# Out:
# [4, 5, 6, 7, 8, 9, 10]

# %% [markdown]
# Now do the actual work to looping over all the 3 hyperparameter ranges each time doing cross-validation to get the best MAE for that iteration.
#
# The number of loops are 567 in this trial:
#
# * len(iteration_range) * len(learning_rate_range) * len(depth_range)
#
# The hyperparameter values and resulting cross validated MAE will be saved to "sensitivity.txt" as it progresses. Since it takes a very long time to run so many loops, the system might crash and we don't want to lose hours worth of data.
#
# Again this next cell take some time, **around 10 hours**.

# %%
# %%time

kfolds=2
i=0
total = len(iteration_range) * len(learning_rate_range) * len(depth_range)
log_file = '/content/drive/MyDrive/Colab Notebooks/data/696/sensitivity.{}.txt'.format(get_now_datetime_filename_str())
results = {
    'trial':{
        'starttime': get_now_datetime_str(),
        'iteration_range': iteration_range,
        'learning_rate_range': learning_rate_range,
        'depth_range': depth_range,
        'kfolds': kfolds
    },
    'runs':[]
}

for iterations in iteration_range:
    for learning_rate in learning_rate_range:
        for depth in depth_range:
            print('{}/{}, {}% - kfolds {}, iterations {}, learning_rate {}, depth {}'.format(i, total, round(((i/total)*100),2), kfolds, iterations, learning_rate, depth))
            hyper_params = best_model_params.copy()
            hyper_params['iterations'] = iterations
            hyper_params['learning_rate'] = learning_rate
            hyper_params['depth'] = depth

            cv_data = cv(
                pool=train_pool,
                params=hyper_params, # use our hyper parameters 
                fold_count=kfolds,
                logging_level='Silent'
            )

            result = {'hyper_params':hyper_params,
                      'cv_data':dict(cv_data.iloc[-1]),
                      'datetime': get_now_datetime_str()}
            results['runs'].append(result)

            with open(log_file, 'w') as sensitivity_file:
                sensitivity_file.write(json.dumps(results,indent=4))

            i+=1
# Out:
# 0/567, 0.0% - kfolds 10, iterations 769, learning_rate 0.013078329691142504, depth 4
# 1/567, 0.18% - kfolds 10, iterations 769, learning_rate 0.013078329691142504, depth 5
# 2/567, 0.35% - kfolds 10, iterations 769, learning_rate 0.013078329691142504, depth 6
# 3/567, 0.53% - kfolds 10, iterations 769, learning_rate 0.013078329691142504, depth 7
# 4/567, 0.71% - kfolds 10, iterations 769, learning_rate 0.013078329691142504, depth 8
# 5/567, 0.88% - kfolds 10, iterations 769, learning_rate 0.013078329691142504, depth 9
# 6/567, 1.06% - kfolds 10, iterations 769, learning_rate 0.013078329691142504, depth 10
# 7/567, 1.23% - kfolds 10, iterations 769, learning_rate 0.022887076959499382, depth 4
# 8/567, 1.41% - kfolds 10, iterations 769, learning_rate 0.022887076959499382, depth 5
# 9/567, 1.59% - kfolds 10, iterations 769, learning_rate 0.022887076959499382, depth 6
# 10/567, 1.76% - kfolds 10, iterations 769, learning_rate 0.022887076959499382, depth 7
# 11/567, 1.94% - kfolds 10, iterations 769, learning_rate 0.022887076959499382, depth 8
# 12/567, 2.12% - kfolds 10, iterations 769, learning_rate 0.022887076959499382, depth 9
# 13/567, 2.29% - kfolds 10, iterations 769, learning_rate 0.022887076959499382, depth 10
# 14/567, 2.47% - kfolds 10, iterations 769, learning_rate 0.03269582422785626, depth 4
# 15/567, 2.65% - kfolds 10, iterations 769, learning_rate 0.03269582422785626, depth 5
# 16/567, 2.82% - kfolds 10, iterations 769, learning_rate 0.03269582422785626, depth 6
# 17/567, 3.0% - kfolds 10, iterations 769, learning_rate 0.03269582422785626, depth 7
# 18/567, 3.17% - kfolds 10, iterations 769, learning_rate 0.03269582422785626, depth 8
# 19/567, 3.35% - kfolds 10, iterations 769, learning_rate 0.03269582422785626, depth 9
# 20/567, 3.53% - kfolds 10, iterations 769, learning_rate 0.03269582422785626, depth 10
# 21/567, 3.7% - kfolds 10, iterations 769, learning_rate 0.04250457149621314, depth 4
# 22/567, 3.88% - kfolds 10, iterations 769, learning_rate 0.04250457149621314, depth 5
# 23/567, 4.06% - kfolds 10, iterations 769, learning_rate 0.04250457149621314, depth 6
# 24/567, 4.23% - kfolds 10, iterations 769, learning_rate 0.04250457149621314, depth 7
# 25/567, 4.41% - kfolds 10, iterations 769, learning_rate 0.04250457149621314, depth 8
# 26/567, 4.59% - kfolds 10, iterations 769, learning_rate 0.04250457149621314, depth 9
# 27/567, 4.76% - kfolds 10, iterations 769, learning_rate 0.04250457149621314, depth 10
# 28/567, 4.94% - kfolds 10, iterations 769, learning_rate 0.052313318764570016, depth 4
# 29/567, 5.11% - kfolds 10, iterations 769, learning_rate 0.052313318764570016, depth 5
# 30/567, 5.29% - kfolds 10, iterations 769, learning_rate 0.052313318764570016, depth 6
# 31/567, 5.47% - kfolds 10, iterations 769, learning_rate 0.052313318764570016, depth 7
# 32/567, 5.64% - kfolds 10, iterations 769, learning_rate 0.052313318764570016, depth 8
# 33/567, 5.82% - kfolds 10, iterations 769, learning_rate 0.052313318764570016, depth 9
# 34/567, 6.0% - kfolds 10, iterations 769, learning_rate 0.052313318764570016, depth 10
# 35/567, 6.17% - kfolds 10, iterations 769, learning_rate 0.062122066032926894, depth 4
# 36/567, 6.35% - kfolds 10, iterations 769, learning_rate 0.062122066032926894, depth 5
# 37/567, 6.53% - kfolds 10, iterations 769, learning_rate 0.062122066032926894, depth 6
# 38/567, 6.7% - kfolds 10, iterations 769, learning_rate 0.062122066032926894, depth 7
# 39/567, 6.88% - kfolds 10, iterations 769, learning_rate 0.062122066032926894, depth 8
# 40/567, 7.05% - kfolds 10, iterations 769, learning_rate 0.062122066032926894, depth 9
# 41/567, 7.23% - kfolds 10, iterations 769, learning_rate 0.062122066032926894, depth 10
# 42/567, 7.41% - kfolds 10, iterations 769, learning_rate 0.07193081330128377, depth 4
# 43/567, 7.58% - kfolds 10, iterations 769, learning_rate 0.07193081330128377, depth 5
# 44/567, 7.76% - kfolds 10, iterations 769, learning_rate 0.07193081330128377, depth 6
# 45/567, 7.94% - kfolds 10, iterations 769, learning_rate 0.07193081330128377, depth 7
# 46/567, 8.11% - kfolds 10, iterations 769, learning_rate 0.07193081330128377, depth 8
# 47/567, 8.29% - kfolds 10, iterations 769, learning_rate 0.07193081330128377, depth 9
# 48/567, 8.47% - kfolds 10, iterations 769, learning_rate 0.07193081330128377, depth 10
# 49/567, 8.64% - kfolds 10, iterations 769, learning_rate 0.08173956056964066, depth 4
# 50/567, 8.82% - kfolds 10, iterations 769, learning_rate 0.08173956056964066, depth 5
# 51/567, 8.99% - kfolds 10, iterations 769, learning_rate 0.08173956056964066, depth 6
# 52/567, 9.17% - kfolds 10, iterations 769, learning_rate 0.08173956056964066, depth 7
# 53/567, 9.35% - kfolds 10, iterations 769, learning_rate 0.08173956056964066, depth 8
# 54/567, 9.52% - kfolds 10, iterations 769, learning_rate 0.08173956056964066, depth 9
# 55/567, 9.7% - kfolds 10, iterations 769, learning_rate 0.08173956056964066, depth 10
# 56/567, 9.88% - kfolds 10, iterations 769, learning_rate 0.09154830783799753, depth 4
# 57/567, 10.05% - kfolds 10, iterations 769, learning_rate 0.09154830783799753, depth 5
# 58/567, 10.23% - kfolds 10, iterations 769, learning_rate 0.09154830783799753, depth 6
# 59/567, 10.41% - kfolds 10, iterations 769, learning_rate 0.09154830783799753, depth 7
# 60/567, 10.58% - kfolds 10, iterations 769, learning_rate 0.09154830783799753, depth 8
# 61/567, 10.76% - kfolds 10, iterations 769, learning_rate 0.09154830783799753, depth 9
# 62/567, 10.93% - kfolds 10, iterations 769, learning_rate 0.09154830783799753, depth 10
# 63/567, 11.11% - kfolds 10, iterations 961, learning_rate 0.013078329691142504, depth 4
# 64/567, 11.29% - kfolds 10, iterations 961, learning_rate 0.013078329691142504, depth 5
# 65/567, 11.46% - kfolds 10, iterations 961, learning_rate 0.013078329691142504, depth 6
# 66/567, 11.64% - kfolds 10, iterations 961, learning_rate 0.013078329691142504, depth 7
# 67/567, 11.82% - kfolds 10, iterations 961, learning_rate 0.013078329691142504, depth 8
# 68/567, 11.99% - kfolds 10, iterations 961, learning_rate 0.013078329691142504, depth 9
# 69/567, 12.17% - kfolds 10, iterations 961, learning_rate 0.013078329691142504, depth 10
# 70/567, 12.35% - kfolds 10, iterations 961, learning_rate 0.022887076959499382, depth 4
# 71/567, 12.52% - kfolds 10, iterations 961, learning_rate 0.022887076959499382, depth 5
# 72/567, 12.7% - kfolds 10, iterations 961, learning_rate 0.022887076959499382, depth 6
# 73/567, 12.87% - kfolds 10, iterations 961, learning_rate 0.022887076959499382, depth 7
# 74/567, 13.05% - kfolds 10, iterations 961, learning_rate 0.022887076959499382, depth 8
# 75/567, 13.23% - kfolds 10, iterations 961, learning_rate 0.022887076959499382, depth 9
# 76/567, 13.4% - kfolds 10, iterations 961, learning_rate 0.022887076959499382, depth 10
# 77/567, 13.58% - kfolds 10, iterations 961, learning_rate 0.03269582422785626, depth 4
# 78/567, 13.76% - kfolds 10, iterations 961, learning_rate 0.03269582422785626, depth 5
# 79/567, 13.93% - kfolds 10, iterations 961, learning_rate 0.03269582422785626, depth 6
# 80/567, 14.11% - kfolds 10, iterations 961, learning_rate 0.03269582422785626, depth 7
# 81/567, 14.29% - kfolds 10, iterations 961, learning_rate 0.03269582422785626, depth 8
# 82/567, 14.46% - kfolds 10, iterations 961, learning_rate 0.03269582422785626, depth 9
# 83/567, 14.64% - kfolds 10, iterations 961, learning_rate 0.03269582422785626, depth 10
# 84/567, 14.81% - kfolds 10, iterations 961, learning_rate 0.04250457149621314, depth 4
# 85/567, 14.99% - kfolds 10, iterations 961, learning_rate 0.04250457149621314, depth 5
# 86/567, 15.17% - kfolds 10, iterations 961, learning_rate 0.04250457149621314, depth 6
# 87/567, 15.34% - kfolds 10, iterations 961, learning_rate 0.04250457149621314, depth 7
# 88/567, 15.52% - kfolds 10, iterations 961, learning_rate 0.04250457149621314, depth 8
# 89/567, 15.7% - kfolds 10, iterations 961, learning_rate 0.04250457149621314, depth 9
# 90/567, 15.87% - kfolds 10, iterations 961, learning_rate 0.04250457149621314, depth 10
# 91/567, 16.05% - kfolds 10, iterations 961, learning_rate 0.052313318764570016, depth 4
# 92/567, 16.23% - kfolds 10, iterations 961, learning_rate 0.052313318764570016, depth 5
# 93/567, 16.4% - kfolds 10, iterations 961, learning_rate 0.052313318764570016, depth 6
# 94/567, 16.58% - kfolds 10, iterations 961, learning_rate 0.052313318764570016, depth 7
# 95/567, 16.75% - kfolds 10, iterations 961, learning_rate 0.052313318764570016, depth 8
# 96/567, 16.93% - kfolds 10, iterations 961, learning_rate 0.052313318764570016, depth 9
# 97/567, 17.11% - kfolds 10, iterations 961, learning_rate 0.052313318764570016, depth 10
# 98/567, 17.28% - kfolds 10, iterations 961, learning_rate 0.062122066032926894, depth 4
# 99/567, 17.46% - kfolds 10, iterations 961, learning_rate 0.062122066032926894, depth 5
# 100/567, 17.64% - kfolds 10, iterations 961, learning_rate 0.062122066032926894, depth 6
# 101/567, 17.81% - kfolds 10, iterations 961, learning_rate 0.062122066032926894, depth 7
# 102/567, 17.99% - kfolds 10, iterations 961, learning_rate 0.062122066032926894, depth 8
# 103/567, 18.17% - kfolds 10, iterations 961, learning_rate 0.062122066032926894, depth 9
# 104/567, 18.34% - kfolds 10, iterations 961, learning_rate 0.062122066032926894, depth 10
# 105/567, 18.52% - kfolds 10, iterations 961, learning_rate 0.07193081330128377, depth 4
# 106/567, 18.69% - kfolds 10, iterations 961, learning_rate 0.07193081330128377, depth 5
# 107/567, 18.87% - kfolds 10, iterations 961, learning_rate 0.07193081330128377, depth 6
# 108/567, 19.05% - kfolds 10, iterations 961, learning_rate 0.07193081330128377, depth 7
# 109/567, 19.22% - kfolds 10, iterations 961, learning_rate 0.07193081330128377, depth 8
# 110/567, 19.4% - kfolds 10, iterations 961, learning_rate 0.07193081330128377, depth 9
# 111/567, 19.58% - kfolds 10, iterations 961, learning_rate 0.07193081330128377, depth 10
# 112/567, 19.75% - kfolds 10, iterations 961, learning_rate 0.08173956056964066, depth 4
# 113/567, 19.93% - kfolds 10, iterations 961, learning_rate 0.08173956056964066, depth 5
# 114/567, 20.11% - kfolds 10, iterations 961, learning_rate 0.08173956056964066, depth 6
# 115/567, 20.28% - kfolds 10, iterations 961, learning_rate 0.08173956056964066, depth 7
# 116/567, 20.46% - kfolds 10, iterations 961, learning_rate 0.08173956056964066, depth 8
# 117/567, 20.63% - kfolds 10, iterations 961, learning_rate 0.08173956056964066, depth 9
# 118/567, 20.81% - kfolds 10, iterations 961, learning_rate 0.08173956056964066, depth 10
# 119/567, 20.99% - kfolds 10, iterations 961, learning_rate 0.09154830783799753, depth 4
# 120/567, 21.16% - kfolds 10, iterations 961, learning_rate 0.09154830783799753, depth 5
# 121/567, 21.34% - kfolds 10, iterations 961, learning_rate 0.09154830783799753, depth 6
# 122/567, 21.52% - kfolds 10, iterations 961, learning_rate 0.09154830783799753, depth 7
# 123/567, 21.69% - kfolds 10, iterations 961, learning_rate 0.09154830783799753, depth 8
# 124/567, 21.87% - kfolds 10, iterations 961, learning_rate 0.09154830783799753, depth 9
# 125/567, 22.05% - kfolds 10, iterations 961, learning_rate 0.09154830783799753, depth 10
# 126/567, 22.22% - kfolds 10, iterations 1153, learning_rate 0.013078329691142504, depth 4
# 127/567, 22.4% - kfolds 10, iterations 1153, learning_rate 0.013078329691142504, depth 5
# 128/567, 22.57% - kfolds 10, iterations 1153, learning_rate 0.013078329691142504, depth 6
# 129/567, 22.75% - kfolds 10, iterations 1153, learning_rate 0.013078329691142504, depth 7
# 130/567, 22.93% - kfolds 10, iterations 1153, learning_rate 0.013078329691142504, depth 8
# 131/567, 23.1% - kfolds 10, iterations 1153, learning_rate 0.013078329691142504, depth 9
# 132/567, 23.28% - kfolds 10, iterations 1153, learning_rate 0.013078329691142504, depth 10
# 133/567, 23.46% - kfolds 10, iterations 1153, learning_rate 0.022887076959499382, depth 4
# 134/567, 23.63% - kfolds 10, iterations 1153, learning_rate 0.022887076959499382, depth 5
# 135/567, 23.81% - kfolds 10, iterations 1153, learning_rate 0.022887076959499382, depth 6
# 136/567, 23.99% - kfolds 10, iterations 1153, learning_rate 0.022887076959499382, depth 7
# 137/567, 24.16% - kfolds 10, iterations 1153, learning_rate 0.022887076959499382, depth 8
# 138/567, 24.34% - kfolds 10, iterations 1153, learning_rate 0.022887076959499382, depth 9
# 139/567, 24.51% - kfolds 10, iterations 1153, learning_rate 0.022887076959499382, depth 10
# 140/567, 24.69% - kfolds 10, iterations 1153, learning_rate 0.03269582422785626, depth 4
# 141/567, 24.87% - kfolds 10, iterations 1153, learning_rate 0.03269582422785626, depth 5
# 142/567, 25.04% - kfolds 10, iterations 1153, learning_rate 0.03269582422785626, depth 6
# 143/567, 25.22% - kfolds 10, iterations 1153, learning_rate 0.03269582422785626, depth 7
# 144/567, 25.4% - kfolds 10, iterations 1153, learning_rate 0.03269582422785626, depth 8
# 145/567, 25.57% - kfolds 10, iterations 1153, learning_rate 0.03269582422785626, depth 9
# 146/567, 25.75% - kfolds 10, iterations 1153, learning_rate 0.03269582422785626, depth 10
# 147/567, 25.93% - kfolds 10, iterations 1153, learning_rate 0.04250457149621314, depth 4
# 148/567, 26.1% - kfolds 10, iterations 1153, learning_rate 0.04250457149621314, depth 5
# 149/567, 26.28% - kfolds 10, iterations 1153, learning_rate 0.04250457149621314, depth 6
# 150/567, 26.46% - kfolds 10, iterations 1153, learning_rate 0.04250457149621314, depth 7
# 151/567, 26.63% - kfolds 10, iterations 1153, learning_rate 0.04250457149621314, depth 8
# 152/567, 26.81% - kfolds 10, iterations 1153, learning_rate 0.04250457149621314, depth 9
# 153/567, 26.98% - kfolds 10, iterations 1153, learning_rate 0.04250457149621314, depth 10
# 154/567, 27.16% - kfolds 10, iterations 1153, learning_rate 0.052313318764570016, depth 4
# 155/567, 27.34% - kfolds 10, iterations 1153, learning_rate 0.052313318764570016, depth 5
# 156/567, 27.51% - kfolds 10, iterations 1153, learning_rate 0.052313318764570016, depth 6
# 157/567, 27.69% - kfolds 10, iterations 1153, learning_rate 0.052313318764570016, depth 7
# 158/567, 27.87% - kfolds 10, iterations 1153, learning_rate 0.052313318764570016, depth 8
# 159/567, 28.04% - kfolds 10, iterations 1153, learning_rate 0.052313318764570016, depth 9
# 160/567, 28.22% - kfolds 10, iterations 1153, learning_rate 0.052313318764570016, depth 10
# 161/567, 28.4% - kfolds 10, iterations 1153, learning_rate 0.062122066032926894, depth 4
# 162/567, 28.57% - kfolds 10, iterations 1153, learning_rate 0.062122066032926894, depth 5
# 163/567, 28.75% - kfolds 10, iterations 1153, learning_rate 0.062122066032926894, depth 6
# 164/567, 28.92% - kfolds 10, iterations 1153, learning_rate 0.062122066032926894, depth 7
# 165/567, 29.1% - kfolds 10, iterations 1153, learning_rate 0.062122066032926894, depth 8
# 166/567, 29.28% - kfolds 10, iterations 1153, learning_rate 0.062122066032926894, depth 9
# 167/567, 29.45% - kfolds 10, iterations 1153, learning_rate 0.062122066032926894, depth 10
# 168/567, 29.63% - kfolds 10, iterations 1153, learning_rate 0.07193081330128377, depth 4
# 169/567, 29.81% - kfolds 10, iterations 1153, learning_rate 0.07193081330128377, depth 5
# 170/567, 29.98% - kfolds 10, iterations 1153, learning_rate 0.07193081330128377, depth 6
# 171/567, 30.16% - kfolds 10, iterations 1153, learning_rate 0.07193081330128377, depth 7
# 172/567, 30.34% - kfolds 10, iterations 1153, learning_rate 0.07193081330128377, depth 8
# 173/567, 30.51% - kfolds 10, iterations 1153, learning_rate 0.07193081330128377, depth 9
# 174/567, 30.69% - kfolds 10, iterations 1153, learning_rate 0.07193081330128377, depth 10
# 175/567, 30.86% - kfolds 10, iterations 1153, learning_rate 0.08173956056964066, depth 4
# 176/567, 31.04% - kfolds 10, iterations 1153, learning_rate 0.08173956056964066, depth 5
# 177/567, 31.22% - kfolds 10, iterations 1153, learning_rate 0.08173956056964066, depth 6
# 178/567, 31.39% - kfolds 10, iterations 1153, learning_rate 0.08173956056964066, depth 7
# 179/567, 31.57% - kfolds 10, iterations 1153, learning_rate 0.08173956056964066, depth 8
# 180/567, 31.75% - kfolds 10, iterations 1153, learning_rate 0.08173956056964066, depth 9
# 181/567, 31.92% - kfolds 10, iterations 1153, learning_rate 0.08173956056964066, depth 10
# 182/567, 32.1% - kfolds 10, iterations 1153, learning_rate 0.09154830783799753, depth 4
# 183/567, 32.28% - kfolds 10, iterations 1153, learning_rate 0.09154830783799753, depth 5
# 184/567, 32.45% - kfolds 10, iterations 1153, learning_rate 0.09154830783799753, depth 6
# 185/567, 32.63% - kfolds 10, iterations 1153, learning_rate 0.09154830783799753, depth 7
# 186/567, 32.8% - kfolds 10, iterations 1153, learning_rate 0.09154830783799753, depth 8
# 187/567, 32.98% - kfolds 10, iterations 1153, learning_rate 0.09154830783799753, depth 9
# 188/567, 33.16% - kfolds 10, iterations 1153, learning_rate 0.09154830783799753, depth 10
# 189/567, 33.33% - kfolds 10, iterations 1345, learning_rate 0.013078329691142504, depth 4
# 190/567, 33.51% - kfolds 10, iterations 1345, learning_rate 0.013078329691142504, depth 5
# 191/567, 33.69% - kfolds 10, iterations 1345, learning_rate 0.013078329691142504, depth 6
# 192/567, 33.86% - kfolds 10, iterations 1345, learning_rate 0.013078329691142504, depth 7
# 193/567, 34.04% - kfolds 10, iterations 1345, learning_rate 0.013078329691142504, depth 8
# 194/567, 34.22% - kfolds 10, iterations 1345, learning_rate 0.013078329691142504, depth 9
# 195/567, 34.39% - kfolds 10, iterations 1345, learning_rate 0.013078329691142504, depth 10
# 196/567, 34.57% - kfolds 10, iterations 1345, learning_rate 0.022887076959499382, depth 4
# 197/567, 34.74% - kfolds 10, iterations 1345, learning_rate 0.022887076959499382, depth 5
# 198/567, 34.92% - kfolds 10, iterations 1345, learning_rate 0.022887076959499382, depth 6
# 199/567, 35.1% - kfolds 10, iterations 1345, learning_rate 0.022887076959499382, depth 7
# 200/567, 35.27% - kfolds 10, iterations 1345, learning_rate 0.022887076959499382, depth 8
# 201/567, 35.45% - kfolds 10, iterations 1345, learning_rate 0.022887076959499382, depth 9
# 202/567, 35.63% - kfolds 10, iterations 1345, learning_rate 0.022887076959499382, depth 10
# 203/567, 35.8% - kfolds 10, iterations 1345, learning_rate 0.03269582422785626, depth 4
# 204/567, 35.98% - kfolds 10, iterations 1345, learning_rate 0.03269582422785626, depth 5
# 205/567, 36.16% - kfolds 10, iterations 1345, learning_rate 0.03269582422785626, depth 6
# 206/567, 36.33% - kfolds 10, iterations 1345, learning_rate 0.03269582422785626, depth 7
# 207/567, 36.51% - kfolds 10, iterations 1345, learning_rate 0.03269582422785626, depth 8
# 208/567, 36.68% - kfolds 10, iterations 1345, learning_rate 0.03269582422785626, depth 9
# 209/567, 36.86% - kfolds 10, iterations 1345, learning_rate 0.03269582422785626, depth 10
# 210/567, 37.04% - kfolds 10, iterations 1345, learning_rate 0.04250457149621314, depth 4
# 211/567, 37.21% - kfolds 10, iterations 1345, learning_rate 0.04250457149621314, depth 5
# 212/567, 37.39% - kfolds 10, iterations 1345, learning_rate 0.04250457149621314, depth 6
# 213/567, 37.57% - kfolds 10, iterations 1345, learning_rate 0.04250457149621314, depth 7
# 214/567, 37.74% - kfolds 10, iterations 1345, learning_rate 0.04250457149621314, depth 8
# 215/567, 37.92% - kfolds 10, iterations 1345, learning_rate 0.04250457149621314, depth 9
# 216/567, 38.1% - kfolds 10, iterations 1345, learning_rate 0.04250457149621314, depth 10
# 217/567, 38.27% - kfolds 10, iterations 1345, learning_rate 0.052313318764570016, depth 4
# 218/567, 38.45% - kfolds 10, iterations 1345, learning_rate 0.052313318764570016, depth 5
# 219/567, 38.62% - kfolds 10, iterations 1345, learning_rate 0.052313318764570016, depth 6
# 220/567, 38.8% - kfolds 10, iterations 1345, learning_rate 0.052313318764570016, depth 7
# 221/567, 38.98% - kfolds 10, iterations 1345, learning_rate 0.052313318764570016, depth 8
# 222/567, 39.15% - kfolds 10, iterations 1345, learning_rate 0.052313318764570016, depth 9
# 223/567, 39.33% - kfolds 10, iterations 1345, learning_rate 0.052313318764570016, depth 10
# 224/567, 39.51% - kfolds 10, iterations 1345, learning_rate 0.062122066032926894, depth 4
# 225/567, 39.68% - kfolds 10, iterations 1345, learning_rate 0.062122066032926894, depth 5
# 226/567, 39.86% - kfolds 10, iterations 1345, learning_rate 0.062122066032926894, depth 6
# 227/567, 40.04% - kfolds 10, iterations 1345, learning_rate 0.062122066032926894, depth 7
# 228/567, 40.21% - kfolds 10, iterations 1345, learning_rate 0.062122066032926894, depth 8
# 229/567, 40.39% - kfolds 10, iterations 1345, learning_rate 0.062122066032926894, depth 9
# 230/567, 40.56% - kfolds 10, iterations 1345, learning_rate 0.062122066032926894, depth 10
# 231/567, 40.74% - kfolds 10, iterations 1345, learning_rate 0.07193081330128377, depth 4
# 232/567, 40.92% - kfolds 10, iterations 1345, learning_rate 0.07193081330128377, depth 5
# 233/567, 41.09% - kfolds 10, iterations 1345, learning_rate 0.07193081330128377, depth 6
# 234/567, 41.27% - kfolds 10, iterations 1345, learning_rate 0.07193081330128377, depth 7
# 235/567, 41.45% - kfolds 10, iterations 1345, learning_rate 0.07193081330128377, depth 8
# 236/567, 41.62% - kfolds 10, iterations 1345, learning_rate 0.07193081330128377, depth 9
# 237/567, 41.8% - kfolds 10, iterations 1345, learning_rate 0.07193081330128377, depth 10
# 238/567, 41.98% - kfolds 10, iterations 1345, learning_rate 0.08173956056964066, depth 4
# 239/567, 42.15% - kfolds 10, iterations 1345, learning_rate 0.08173956056964066, depth 5
# 240/567, 42.33% - kfolds 10, iterations 1345, learning_rate 0.08173956056964066, depth 6
# 241/567, 42.5% - kfolds 10, iterations 1345, learning_rate 0.08173956056964066, depth 7
# 242/567, 42.68% - kfolds 10, iterations 1345, learning_rate 0.08173956056964066, depth 8
# 243/567, 42.86% - kfolds 10, iterations 1345, learning_rate 0.08173956056964066, depth 9
# 244/567, 43.03% - kfolds 10, iterations 1345, learning_rate 0.08173956056964066, depth 10
# 245/567, 43.21% - kfolds 10, iterations 1345, learning_rate 0.09154830783799753, depth 4
# 246/567, 43.39% - kfolds 10, iterations 1345, learning_rate 0.09154830783799753, depth 5
# 247/567, 43.56% - kfolds 10, iterations 1345, learning_rate 0.09154830783799753, depth 6
# 248/567, 43.74% - kfolds 10, iterations 1345, learning_rate 0.09154830783799753, depth 7
# 249/567, 43.92% - kfolds 10, iterations 1345, learning_rate 0.09154830783799753, depth 8
# 250/567, 44.09% - kfolds 10, iterations 1345, learning_rate 0.09154830783799753, depth 9
# 251/567, 44.27% - kfolds 10, iterations 1345, learning_rate 0.09154830783799753, depth 10
# 252/567, 44.44% - kfolds 10, iterations 1538, learning_rate 0.013078329691142504, depth 4
# 253/567, 44.62% - kfolds 10, iterations 1538, learning_rate 0.013078329691142504, depth 5
# 254/567, 44.8% - kfolds 10, iterations 1538, learning_rate 0.013078329691142504, depth 6
# 255/567, 44.97% - kfolds 10, iterations 1538, learning_rate 0.013078329691142504, depth 7
# 256/567, 45.15% - kfolds 10, iterations 1538, learning_rate 0.013078329691142504, depth 8
# 257/567, 45.33% - kfolds 10, iterations 1538, learning_rate 0.013078329691142504, depth 9
# 258/567, 45.5% - kfolds 10, iterations 1538, learning_rate 0.013078329691142504, depth 10
# 259/567, 45.68% - kfolds 10, iterations 1538, learning_rate 0.022887076959499382, depth 4
# 260/567, 45.86% - kfolds 10, iterations 1538, learning_rate 0.022887076959499382, depth 5
# 261/567, 46.03% - kfolds 10, iterations 1538, learning_rate 0.022887076959499382, depth 6
# 262/567, 46.21% - kfolds 10, iterations 1538, learning_rate 0.022887076959499382, depth 7
# 263/567, 46.38% - kfolds 10, iterations 1538, learning_rate 0.022887076959499382, depth 8
# 264/567, 46.56% - kfolds 10, iterations 1538, learning_rate 0.022887076959499382, depth 9
# 265/567, 46.74% - kfolds 10, iterations 1538, learning_rate 0.022887076959499382, depth 10
# 266/567, 46.91% - kfolds 10, iterations 1538, learning_rate 0.03269582422785626, depth 4
# 267/567, 47.09% - kfolds 10, iterations 1538, learning_rate 0.03269582422785626, depth 5
# 268/567, 47.27% - kfolds 10, iterations 1538, learning_rate 0.03269582422785626, depth 6
# 269/567, 47.44% - kfolds 10, iterations 1538, learning_rate 0.03269582422785626, depth 7
# 270/567, 47.62% - kfolds 10, iterations 1538, learning_rate 0.03269582422785626, depth 8
# 271/567, 47.8% - kfolds 10, iterations 1538, learning_rate 0.03269582422785626, depth 9
# 272/567, 47.97% - kfolds 10, iterations 1538, learning_rate 0.03269582422785626, depth 10
# 273/567, 48.15% - kfolds 10, iterations 1538, learning_rate 0.04250457149621314, depth 4
# 274/567, 48.32% - kfolds 10, iterations 1538, learning_rate 0.04250457149621314, depth 5
# 275/567, 48.5% - kfolds 10, iterations 1538, learning_rate 0.04250457149621314, depth 6
# 276/567, 48.68% - kfolds 10, iterations 1538, learning_rate 0.04250457149621314, depth 7
# 277/567, 48.85% - kfolds 10, iterations 1538, learning_rate 0.04250457149621314, depth 8
# 278/567, 49.03% - kfolds 10, iterations 1538, learning_rate 0.04250457149621314, depth 9
# 279/567, 49.21% - kfolds 10, iterations 1538, learning_rate 0.04250457149621314, depth 10
# 280/567, 49.38% - kfolds 10, iterations 1538, learning_rate 0.052313318764570016, depth 4
# 281/567, 49.56% - kfolds 10, iterations 1538, learning_rate 0.052313318764570016, depth 5
# 282/567, 49.74% - kfolds 10, iterations 1538, learning_rate 0.052313318764570016, depth 6
# 283/567, 49.91% - kfolds 10, iterations 1538, learning_rate 0.052313318764570016, depth 7
# 284/567, 50.09% - kfolds 10, iterations 1538, learning_rate 0.052313318764570016, depth 8
# 285/567, 50.26% - kfolds 10, iterations 1538, learning_rate 0.052313318764570016, depth 9
# 286/567, 50.44% - kfolds 10, iterations 1538, learning_rate 0.052313318764570016, depth 10
# 287/567, 50.62% - kfolds 10, iterations 1538, learning_rate 0.062122066032926894, depth 4
# 288/567, 50.79% - kfolds 10, iterations 1538, learning_rate 0.062122066032926894, depth 5
# 289/567, 50.97% - kfolds 10, iterations 1538, learning_rate 0.062122066032926894, depth 6
# 290/567, 51.15% - kfolds 10, iterations 1538, learning_rate 0.062122066032926894, depth 7
# 291/567, 51.32% - kfolds 10, iterations 1538, learning_rate 0.062122066032926894, depth 8
# 292/567, 51.5% - kfolds 10, iterations 1538, learning_rate 0.062122066032926894, depth 9
# 293/567, 51.68% - kfolds 10, iterations 1538, learning_rate 0.062122066032926894, depth 10
# 294/567, 51.85% - kfolds 10, iterations 1538, learning_rate 0.07193081330128377, depth 4
# 295/567, 52.03% - kfolds 10, iterations 1538, learning_rate 0.07193081330128377, depth 5
# 296/567, 52.2% - kfolds 10, iterations 1538, learning_rate 0.07193081330128377, depth 6
# 297/567, 52.38% - kfolds 10, iterations 1538, learning_rate 0.07193081330128377, depth 7
# 298/567, 52.56% - kfolds 10, iterations 1538, learning_rate 0.07193081330128377, depth 8
# 299/567, 52.73% - kfolds 10, iterations 1538, learning_rate 0.07193081330128377, depth 9
# 300/567, 52.91% - kfolds 10, iterations 1538, learning_rate 0.07193081330128377, depth 10
# 301/567, 53.09% - kfolds 10, iterations 1538, learning_rate 0.08173956056964066, depth 4
# 302/567, 53.26% - kfolds 10, iterations 1538, learning_rate 0.08173956056964066, depth 5
# 303/567, 53.44% - kfolds 10, iterations 1538, learning_rate 0.08173956056964066, depth 6
# 304/567, 53.62% - kfolds 10, iterations 1538, learning_rate 0.08173956056964066, depth 7
# 305/567, 53.79% - kfolds 10, iterations 1538, learning_rate 0.08173956056964066, depth 8
# 306/567, 53.97% - kfolds 10, iterations 1538, learning_rate 0.08173956056964066, depth 9
# 307/567, 54.14% - kfolds 10, iterations 1538, learning_rate 0.08173956056964066, depth 10
# 308/567, 54.32% - kfolds 10, iterations 1538, learning_rate 0.09154830783799753, depth 4
# 309/567, 54.5% - kfolds 10, iterations 1538, learning_rate 0.09154830783799753, depth 5
# 310/567, 54.67% - kfolds 10, iterations 1538, learning_rate 0.09154830783799753, depth 6
# 311/567, 54.85% - kfolds 10, iterations 1538, learning_rate 0.09154830783799753, depth 7
# 312/567, 55.03% - kfolds 10, iterations 1538, learning_rate 0.09154830783799753, depth 8
# 313/567, 55.2% - kfolds 10, iterations 1538, learning_rate 0.09154830783799753, depth 9
# 314/567, 55.38% - kfolds 10, iterations 1538, learning_rate 0.09154830783799753, depth 10
# 315/567, 55.56% - kfolds 10, iterations 1730, learning_rate 0.013078329691142504, depth 4
# 316/567, 55.73% - kfolds 10, iterations 1730, learning_rate 0.013078329691142504, depth 5
# 317/567, 55.91% - kfolds 10, iterations 1730, learning_rate 0.013078329691142504, depth 6
# 318/567, 56.08% - kfolds 10, iterations 1730, learning_rate 0.013078329691142504, depth 7
# 319/567, 56.26% - kfolds 10, iterations 1730, learning_rate 0.013078329691142504, depth 8
# 320/567, 56.44% - kfolds 10, iterations 1730, learning_rate 0.013078329691142504, depth 9
# 321/567, 56.61% - kfolds 10, iterations 1730, learning_rate 0.013078329691142504, depth 10
# 322/567, 56.79% - kfolds 10, iterations 1730, learning_rate 0.022887076959499382, depth 4
# 323/567, 56.97% - kfolds 10, iterations 1730, learning_rate 0.022887076959499382, depth 5
# 324/567, 57.14% - kfolds 10, iterations 1730, learning_rate 0.022887076959499382, depth 6
# 325/567, 57.32% - kfolds 10, iterations 1730, learning_rate 0.022887076959499382, depth 7
# 326/567, 57.5% - kfolds 10, iterations 1730, learning_rate 0.022887076959499382, depth 8
# 327/567, 57.67% - kfolds 10, iterations 1730, learning_rate 0.022887076959499382, depth 9
# 328/567, 57.85% - kfolds 10, iterations 1730, learning_rate 0.022887076959499382, depth 10
# 329/567, 58.02% - kfolds 10, iterations 1730, learning_rate 0.03269582422785626, depth 4
# 330/567, 58.2% - kfolds 10, iterations 1730, learning_rate 0.03269582422785626, depth 5
# 331/567, 58.38% - kfolds 10, iterations 1730, learning_rate 0.03269582422785626, depth 6
# 332/567, 58.55% - kfolds 10, iterations 1730, learning_rate 0.03269582422785626, depth 7
# 333/567, 58.73% - kfolds 10, iterations 1730, learning_rate 0.03269582422785626, depth 8
# 334/567, 58.91% - kfolds 10, iterations 1730, learning_rate 0.03269582422785626, depth 9
# 335/567, 59.08% - kfolds 10, iterations 1730, learning_rate 0.03269582422785626, depth 10
# 336/567, 59.26% - kfolds 10, iterations 1730, learning_rate 0.04250457149621314, depth 4
# 337/567, 59.44% - kfolds 10, iterations 1730, learning_rate 0.04250457149621314, depth 5
# 338/567, 59.61% - kfolds 10, iterations 1730, learning_rate 0.04250457149621314, depth 6
# 339/567, 59.79% - kfolds 10, iterations 1730, learning_rate 0.04250457149621314, depth 7
# 340/567, 59.96% - kfolds 10, iterations 1730, learning_rate 0.04250457149621314, depth 8
# 341/567, 60.14% - kfolds 10, iterations 1730, learning_rate 0.04250457149621314, depth 9
# 342/567, 60.32% - kfolds 10, iterations 1730, learning_rate 0.04250457149621314, depth 10
# 343/567, 60.49% - kfolds 10, iterations 1730, learning_rate 0.052313318764570016, depth 4
# 344/567, 60.67% - kfolds 10, iterations 1730, learning_rate 0.052313318764570016, depth 5
# 345/567, 60.85% - kfolds 10, iterations 1730, learning_rate 0.052313318764570016, depth 6
# 346/567, 61.02% - kfolds 10, iterations 1730, learning_rate 0.052313318764570016, depth 7
# 347/567, 61.2% - kfolds 10, iterations 1730, learning_rate 0.052313318764570016, depth 8
# 348/567, 61.38% - kfolds 10, iterations 1730, learning_rate 0.052313318764570016, depth 9
# 349/567, 61.55% - kfolds 10, iterations 1730, learning_rate 0.052313318764570016, depth 10
# 350/567, 61.73% - kfolds 10, iterations 1730, learning_rate 0.062122066032926894, depth 4
# 351/567, 61.9% - kfolds 10, iterations 1730, learning_rate 0.062122066032926894, depth 5
# 352/567, 62.08% - kfolds 10, iterations 1730, learning_rate 0.062122066032926894, depth 6
# 353/567, 62.26% - kfolds 10, iterations 1730, learning_rate 0.062122066032926894, depth 7
# 354/567, 62.43% - kfolds 10, iterations 1730, learning_rate 0.062122066032926894, depth 8
# 355/567, 62.61% - kfolds 10, iterations 1730, learning_rate 0.062122066032926894, depth 9
# 356/567, 62.79% - kfolds 10, iterations 1730, learning_rate 0.062122066032926894, depth 10
# 357/567, 62.96% - kfolds 10, iterations 1730, learning_rate 0.07193081330128377, depth 4
# 358/567, 63.14% - kfolds 10, iterations 1730, learning_rate 0.07193081330128377, depth 5
# 359/567, 63.32% - kfolds 10, iterations 1730, learning_rate 0.07193081330128377, depth 6
# 360/567, 63.49% - kfolds 10, iterations 1730, learning_rate 0.07193081330128377, depth 7
# 361/567, 63.67% - kfolds 10, iterations 1730, learning_rate 0.07193081330128377, depth 8
# 362/567, 63.84% - kfolds 10, iterations 1730, learning_rate 0.07193081330128377, depth 9
# 363/567, 64.02% - kfolds 10, iterations 1730, learning_rate 0.07193081330128377, depth 10
# 364/567, 64.2% - kfolds 10, iterations 1730, learning_rate 0.08173956056964066, depth 4
# 365/567, 64.37% - kfolds 10, iterations 1730, learning_rate 0.08173956056964066, depth 5
# 366/567, 64.55% - kfolds 10, iterations 1730, learning_rate 0.08173956056964066, depth 6
# 367/567, 64.73% - kfolds 10, iterations 1730, learning_rate 0.08173956056964066, depth 7
# 368/567, 64.9% - kfolds 10, iterations 1730, learning_rate 0.08173956056964066, depth 8
# 369/567, 65.08% - kfolds 10, iterations 1730, learning_rate 0.08173956056964066, depth 9
# 370/567, 65.26% - kfolds 10, iterations 1730, learning_rate 0.08173956056964066, depth 10
# 371/567, 65.43% - kfolds 10, iterations 1730, learning_rate 0.09154830783799753, depth 4
# 372/567, 65.61% - kfolds 10, iterations 1730, learning_rate 0.09154830783799753, depth 5
# 373/567, 65.78% - kfolds 10, iterations 1730, learning_rate 0.09154830783799753, depth 6
# 374/567, 65.96% - kfolds 10, iterations 1730, learning_rate 0.09154830783799753, depth 7
# 375/567, 66.14% - kfolds 10, iterations 1730, learning_rate 0.09154830783799753, depth 8
# 376/567, 66.31% - kfolds 10, iterations 1730, learning_rate 0.09154830783799753, depth 9
# 377/567, 66.49% - kfolds 10, iterations 1730, learning_rate 0.09154830783799753, depth 10
# 378/567, 66.67% - kfolds 10, iterations 1922, learning_rate 0.013078329691142504, depth 4
# 379/567, 66.84% - kfolds 10, iterations 1922, learning_rate 0.013078329691142504, depth 5
# 380/567, 67.02% - kfolds 10, iterations 1922, learning_rate 0.013078329691142504, depth 6
# 381/567, 67.2% - kfolds 10, iterations 1922, learning_rate 0.013078329691142504, depth 7
# 382/567, 67.37% - kfolds 10, iterations 1922, learning_rate 0.013078329691142504, depth 8
# 383/567, 67.55% - kfolds 10, iterations 1922, learning_rate 0.013078329691142504, depth 9
# 384/567, 67.72% - kfolds 10, iterations 1922, learning_rate 0.013078329691142504, depth 10
# 385/567, 67.9% - kfolds 10, iterations 1922, learning_rate 0.022887076959499382, depth 4
# 386/567, 68.08% - kfolds 10, iterations 1922, learning_rate 0.022887076959499382, depth 5
# 387/567, 68.25% - kfolds 10, iterations 1922, learning_rate 0.022887076959499382, depth 6
# 388/567, 68.43% - kfolds 10, iterations 1922, learning_rate 0.022887076959499382, depth 7
# 389/567, 68.61% - kfolds 10, iterations 1922, learning_rate 0.022887076959499382, depth 8
# 390/567, 68.78% - kfolds 10, iterations 1922, learning_rate 0.022887076959499382, depth 9
# 391/567, 68.96% - kfolds 10, iterations 1922, learning_rate 0.022887076959499382, depth 10
# 392/567, 69.14% - kfolds 10, iterations 1922, learning_rate 0.03269582422785626, depth 4
# 393/567, 69.31% - kfolds 10, iterations 1922, learning_rate 0.03269582422785626, depth 5
# 394/567, 69.49% - kfolds 10, iterations 1922, learning_rate 0.03269582422785626, depth 6
# 395/567, 69.66% - kfolds 10, iterations 1922, learning_rate 0.03269582422785626, depth 7
# 396/567, 69.84% - kfolds 10, iterations 1922, learning_rate 0.03269582422785626, depth 8
# 397/567, 70.02% - kfolds 10, iterations 1922, learning_rate 0.03269582422785626, depth 9
# 398/567, 70.19% - kfolds 10, iterations 1922, learning_rate 0.03269582422785626, depth 10
# 399/567, 70.37% - kfolds 10, iterations 1922, learning_rate 0.04250457149621314, depth 4
# 400/567, 70.55% - kfolds 10, iterations 1922, learning_rate 0.04250457149621314, depth 5
# 401/567, 70.72% - kfolds 10, iterations 1922, learning_rate 0.04250457149621314, depth 6
# 402/567, 70.9% - kfolds 10, iterations 1922, learning_rate 0.04250457149621314, depth 7
# 403/567, 71.08% - kfolds 10, iterations 1922, learning_rate 0.04250457149621314, depth 8
# 404/567, 71.25% - kfolds 10, iterations 1922, learning_rate 0.04250457149621314, depth 9
# 405/567, 71.43% - kfolds 10, iterations 1922, learning_rate 0.04250457149621314, depth 10
# 406/567, 71.6% - kfolds 10, iterations 1922, learning_rate 0.052313318764570016, depth 4
# 407/567, 71.78% - kfolds 10, iterations 1922, learning_rate 0.052313318764570016, depth 5
# 408/567, 71.96% - kfolds 10, iterations 1922, learning_rate 0.052313318764570016, depth 6
# 409/567, 72.13% - kfolds 10, iterations 1922, learning_rate 0.052313318764570016, depth 7
# 410/567, 72.31% - kfolds 10, iterations 1922, learning_rate 0.052313318764570016, depth 8
# 411/567, 72.49% - kfolds 10, iterations 1922, learning_rate 0.052313318764570016, depth 9
# 412/567, 72.66% - kfolds 10, iterations 1922, learning_rate 0.052313318764570016, depth 10
# 413/567, 72.84% - kfolds 10, iterations 1922, learning_rate 0.062122066032926894, depth 4
# 414/567, 73.02% - kfolds 10, iterations 1922, learning_rate 0.062122066032926894, depth 5
# 415/567, 73.19% - kfolds 10, iterations 1922, learning_rate 0.062122066032926894, depth 6
# 416/567, 73.37% - kfolds 10, iterations 1922, learning_rate 0.062122066032926894, depth 7
# 417/567, 73.54% - kfolds 10, iterations 1922, learning_rate 0.062122066032926894, depth 8
# 418/567, 73.72% - kfolds 10, iterations 1922, learning_rate 0.062122066032926894, depth 9
# 419/567, 73.9% - kfolds 10, iterations 1922, learning_rate 0.062122066032926894, depth 10
# 420/567, 74.07% - kfolds 10, iterations 1922, learning_rate 0.07193081330128377, depth 4
# 421/567, 74.25% - kfolds 10, iterations 1922, learning_rate 0.07193081330128377, depth 5
# 422/567, 74.43% - kfolds 10, iterations 1922, learning_rate 0.07193081330128377, depth 6
# 423/567, 74.6% - kfolds 10, iterations 1922, learning_rate 0.07193081330128377, depth 7
# 424/567, 74.78% - kfolds 10, iterations 1922, learning_rate 0.07193081330128377, depth 8
# 425/567, 74.96% - kfolds 10, iterations 1922, learning_rate 0.07193081330128377, depth 9
# 426/567, 75.13% - kfolds 10, iterations 1922, learning_rate 0.07193081330128377, depth 10
# 427/567, 75.31% - kfolds 10, iterations 1922, learning_rate 0.08173956056964066, depth 4
# 428/567, 75.49% - kfolds 10, iterations 1922, learning_rate 0.08173956056964066, depth 5
# 429/567, 75.66% - kfolds 10, iterations 1922, learning_rate 0.08173956056964066, depth 6
# 430/567, 75.84% - kfolds 10, iterations 1922, learning_rate 0.08173956056964066, depth 7
# 431/567, 76.01% - kfolds 10, iterations 1922, learning_rate 0.08173956056964066, depth 8
# 432/567, 76.19% - kfolds 10, iterations 1922, learning_rate 0.08173956056964066, depth 9
# 433/567, 76.37% - kfolds 10, iterations 1922, learning_rate 0.08173956056964066, depth 10
# 434/567, 76.54% - kfolds 10, iterations 1922, learning_rate 0.09154830783799753, depth 4
# 435/567, 76.72% - kfolds 10, iterations 1922, learning_rate 0.09154830783799753, depth 5
# 436/567, 76.9% - kfolds 10, iterations 1922, learning_rate 0.09154830783799753, depth 6
# 437/567, 77.07% - kfolds 10, iterations 1922, learning_rate 0.09154830783799753, depth 7
# 438/567, 77.25% - kfolds 10, iterations 1922, learning_rate 0.09154830783799753, depth 8
# 439/567, 77.43% - kfolds 10, iterations 1922, learning_rate 0.09154830783799753, depth 9
# 440/567, 77.6% - kfolds 10, iterations 1922, learning_rate 0.09154830783799753, depth 10
# 441/567, 77.78% - kfolds 10, iterations 2114, learning_rate 0.013078329691142504, depth 4
# 442/567, 77.95% - kfolds 10, iterations 2114, learning_rate 0.013078329691142504, depth 5
# 443/567, 78.13% - kfolds 10, iterations 2114, learning_rate 0.013078329691142504, depth 6
# 444/567, 78.31% - kfolds 10, iterations 2114, learning_rate 0.013078329691142504, depth 7
# 445/567, 78.48% - kfolds 10, iterations 2114, learning_rate 0.013078329691142504, depth 8
# 446/567, 78.66% - kfolds 10, iterations 2114, learning_rate 0.013078329691142504, depth 9
# 447/567, 78.84% - kfolds 10, iterations 2114, learning_rate 0.013078329691142504, depth 10
# 448/567, 79.01% - kfolds 10, iterations 2114, learning_rate 0.022887076959499382, depth 4
# 449/567, 79.19% - kfolds 10, iterations 2114, learning_rate 0.022887076959499382, depth 5
# 450/567, 79.37% - kfolds 10, iterations 2114, learning_rate 0.022887076959499382, depth 6
# 451/567, 79.54% - kfolds 10, iterations 2114, learning_rate 0.022887076959499382, depth 7
# 452/567, 79.72% - kfolds 10, iterations 2114, learning_rate 0.022887076959499382, depth 8
# 453/567, 79.89% - kfolds 10, iterations 2114, learning_rate 0.022887076959499382, depth 9
# 454/567, 80.07% - kfolds 10, iterations 2114, learning_rate 0.022887076959499382, depth 10
# 455/567, 80.25% - kfolds 10, iterations 2114, learning_rate 0.03269582422785626, depth 4
# 456/567, 80.42% - kfolds 10, iterations 2114, learning_rate 0.03269582422785626, depth 5
# 457/567, 80.6% - kfolds 10, iterations 2114, learning_rate 0.03269582422785626, depth 6
# 458/567, 80.78% - kfolds 10, iterations 2114, learning_rate 0.03269582422785626, depth 7
# 459/567, 80.95% - kfolds 10, iterations 2114, learning_rate 0.03269582422785626, depth 8
# 460/567, 81.13% - kfolds 10, iterations 2114, learning_rate 0.03269582422785626, depth 9
# 461/567, 81.31% - kfolds 10, iterations 2114, learning_rate 0.03269582422785626, depth 10
# 462/567, 81.48% - kfolds 10, iterations 2114, learning_rate 0.04250457149621314, depth 4
# 463/567, 81.66% - kfolds 10, iterations 2114, learning_rate 0.04250457149621314, depth 5
# 464/567, 81.83% - kfolds 10, iterations 2114, learning_rate 0.04250457149621314, depth 6
# 465/567, 82.01% - kfolds 10, iterations 2114, learning_rate 0.04250457149621314, depth 7
# 466/567, 82.19% - kfolds 10, iterations 2114, learning_rate 0.04250457149621314, depth 8
# 467/567, 82.36% - kfolds 10, iterations 2114, learning_rate 0.04250457149621314, depth 9
# 468/567, 82.54% - kfolds 10, iterations 2114, learning_rate 0.04250457149621314, depth 10
# 469/567, 82.72% - kfolds 10, iterations 2114, learning_rate 0.052313318764570016, depth 4
# 470/567, 82.89% - kfolds 10, iterations 2114, learning_rate 0.052313318764570016, depth 5
# 471/567, 83.07% - kfolds 10, iterations 2114, learning_rate 0.052313318764570016, depth 6
# 472/567, 83.25% - kfolds 10, iterations 2114, learning_rate 0.052313318764570016, depth 7
# 473/567, 83.42% - kfolds 10, iterations 2114, learning_rate 0.052313318764570016, depth 8
# 474/567, 83.6% - kfolds 10, iterations 2114, learning_rate 0.052313318764570016, depth 9
# 475/567, 83.77% - kfolds 10, iterations 2114, learning_rate 0.052313318764570016, depth 10
# 476/567, 83.95% - kfolds 10, iterations 2114, learning_rate 0.062122066032926894, depth 4
# 477/567, 84.13% - kfolds 10, iterations 2114, learning_rate 0.062122066032926894, depth 5
# 478/567, 84.3% - kfolds 10, iterations 2114, learning_rate 0.062122066032926894, depth 6
# 479/567, 84.48% - kfolds 10, iterations 2114, learning_rate 0.062122066032926894, depth 7
# 480/567, 84.66% - kfolds 10, iterations 2114, learning_rate 0.062122066032926894, depth 8
# 481/567, 84.83% - kfolds 10, iterations 2114, learning_rate 0.062122066032926894, depth 9
# 482/567, 85.01% - kfolds 10, iterations 2114, learning_rate 0.062122066032926894, depth 10
# 483/567, 85.19% - kfolds 10, iterations 2114, learning_rate 0.07193081330128377, depth 4
# 484/567, 85.36% - kfolds 10, iterations 2114, learning_rate 0.07193081330128377, depth 5
# 485/567, 85.54% - kfolds 10, iterations 2114, learning_rate 0.07193081330128377, depth 6
# 486/567, 85.71% - kfolds 10, iterations 2114, learning_rate 0.07193081330128377, depth 7
# 487/567, 85.89% - kfolds 10, iterations 2114, learning_rate 0.07193081330128377, depth 8
# 488/567, 86.07% - kfolds 10, iterations 2114, learning_rate 0.07193081330128377, depth 9
# 489/567, 86.24% - kfolds 10, iterations 2114, learning_rate 0.07193081330128377, depth 10
# 490/567, 86.42% - kfolds 10, iterations 2114, learning_rate 0.08173956056964066, depth 4
# 491/567, 86.6% - kfolds 10, iterations 2114, learning_rate 0.08173956056964066, depth 5
# 492/567, 86.77% - kfolds 10, iterations 2114, learning_rate 0.08173956056964066, depth 6
# 493/567, 86.95% - kfolds 10, iterations 2114, learning_rate 0.08173956056964066, depth 7
# 494/567, 87.13% - kfolds 10, iterations 2114, learning_rate 0.08173956056964066, depth 8
# 495/567, 87.3% - kfolds 10, iterations 2114, learning_rate 0.08173956056964066, depth 9
# 496/567, 87.48% - kfolds 10, iterations 2114, learning_rate 0.08173956056964066, depth 10
# 497/567, 87.65% - kfolds 10, iterations 2114, learning_rate 0.09154830783799753, depth 4
# 498/567, 87.83% - kfolds 10, iterations 2114, learning_rate 0.09154830783799753, depth 5
# 499/567, 88.01% - kfolds 10, iterations 2114, learning_rate 0.09154830783799753, depth 6
# 500/567, 88.18% - kfolds 10, iterations 2114, learning_rate 0.09154830783799753, depth 7
# 501/567, 88.36% - kfolds 10, iterations 2114, learning_rate 0.09154830783799753, depth 8
# 502/567, 88.54% - kfolds 10, iterations 2114, learning_rate 0.09154830783799753, depth 9
# 503/567, 88.71% - kfolds 10, iterations 2114, learning_rate 0.09154830783799753, depth 10
# 504/567, 88.89% - kfolds 10, iterations 2307, learning_rate 0.013078329691142504, depth 4
# 505/567, 89.07% - kfolds 10, iterations 2307, learning_rate 0.013078329691142504, depth 5
# 506/567, 89.24% - kfolds 10, iterations 2307, learning_rate 0.013078329691142504, depth 6
# 507/567, 89.42% - kfolds 10, iterations 2307, learning_rate 0.013078329691142504, depth 7
# 508/567, 89.59% - kfolds 10, iterations 2307, learning_rate 0.013078329691142504, depth 8
# 509/567, 89.77% - kfolds 10, iterations 2307, learning_rate 0.013078329691142504, depth 9
# 510/567, 89.95% - kfolds 10, iterations 2307, learning_rate 0.013078329691142504, depth 10
# 511/567, 90.12% - kfolds 10, iterations 2307, learning_rate 0.022887076959499382, depth 4
# 512/567, 90.3% - kfolds 10, iterations 2307, learning_rate 0.022887076959499382, depth 5
# 513/567, 90.48% - kfolds 10, iterations 2307, learning_rate 0.022887076959499382, depth 6
# 514/567, 90.65% - kfolds 10, iterations 2307, learning_rate 0.022887076959499382, depth 7
# 515/567, 90.83% - kfolds 10, iterations 2307, learning_rate 0.022887076959499382, depth 8
# 516/567, 91.01% - kfolds 10, iterations 2307, learning_rate 0.022887076959499382, depth 9
# 517/567, 91.18% - kfolds 10, iterations 2307, learning_rate 0.022887076959499382, depth 10
# 518/567, 91.36% - kfolds 10, iterations 2307, learning_rate 0.03269582422785626, depth 4
# 519/567, 91.53% - kfolds 10, iterations 2307, learning_rate 0.03269582422785626, depth 5
# 520/567, 91.71% - kfolds 10, iterations 2307, learning_rate 0.03269582422785626, depth 6
# 521/567, 91.89% - kfolds 10, iterations 2307, learning_rate 0.03269582422785626, depth 7
# 522/567, 92.06% - kfolds 10, iterations 2307, learning_rate 0.03269582422785626, depth 8
# 523/567, 92.24% - kfolds 10, iterations 2307, learning_rate 0.03269582422785626, depth 9
# 524/567, 92.42% - kfolds 10, iterations 2307, learning_rate 0.03269582422785626, depth 10
# 525/567, 92.59% - kfolds 10, iterations 2307, learning_rate 0.04250457149621314, depth 4
# 526/567, 92.77% - kfolds 10, iterations 2307, learning_rate 0.04250457149621314, depth 5
# 527/567, 92.95% - kfolds 10, iterations 2307, learning_rate 0.04250457149621314, depth 6
# 528/567, 93.12% - kfolds 10, iterations 2307, learning_rate 0.04250457149621314, depth 7
# 529/567, 93.3% - kfolds 10, iterations 2307, learning_rate 0.04250457149621314, depth 8
# 530/567, 93.47% - kfolds 10, iterations 2307, learning_rate 0.04250457149621314, depth 9
# 531/567, 93.65% - kfolds 10, iterations 2307, learning_rate 0.04250457149621314, depth 10
# 532/567, 93.83% - kfolds 10, iterations 2307, learning_rate 0.052313318764570016, depth 4
# 533/567, 94.0% - kfolds 10, iterations 2307, learning_rate 0.052313318764570016, depth 5
# 534/567, 94.18% - kfolds 10, iterations 2307, learning_rate 0.052313318764570016, depth 6
# 535/567, 94.36% - kfolds 10, iterations 2307, learning_rate 0.052313318764570016, depth 7
# 536/567, 94.53% - kfolds 10, iterations 2307, learning_rate 0.052313318764570016, depth 8
# 537/567, 94.71% - kfolds 10, iterations 2307, learning_rate 0.052313318764570016, depth 9
# 538/567, 94.89% - kfolds 10, iterations 2307, learning_rate 0.052313318764570016, depth 10
# 539/567, 95.06% - kfolds 10, iterations 2307, learning_rate 0.062122066032926894, depth 4
# 540/567, 95.24% - kfolds 10, iterations 2307, learning_rate 0.062122066032926894, depth 5
# 541/567, 95.41% - kfolds 10, iterations 2307, learning_rate 0.062122066032926894, depth 6
# 542/567, 95.59% - kfolds 10, iterations 2307, learning_rate 0.062122066032926894, depth 7
# 543/567, 95.77% - kfolds 10, iterations 2307, learning_rate 0.062122066032926894, depth 8
# 544/567, 95.94% - kfolds 10, iterations 2307, learning_rate 0.062122066032926894, depth 9
# 545/567, 96.12% - kfolds 10, iterations 2307, learning_rate 0.062122066032926894, depth 10
# 546/567, 96.3% - kfolds 10, iterations 2307, learning_rate 0.07193081330128377, depth 4
# 547/567, 96.47% - kfolds 10, iterations 2307, learning_rate 0.07193081330128377, depth 5
# 548/567, 96.65% - kfolds 10, iterations 2307, learning_rate 0.07193081330128377, depth 6
# 549/567, 96.83% - kfolds 10, iterations 2307, learning_rate 0.07193081330128377, depth 7
# 550/567, 97.0% - kfolds 10, iterations 2307, learning_rate 0.07193081330128377, depth 8
# 551/567, 97.18% - kfolds 10, iterations 2307, learning_rate 0.07193081330128377, depth 9
# 552/567, 97.35% - kfolds 10, iterations 2307, learning_rate 0.07193081330128377, depth 10
# 553/567, 97.53% - kfolds 10, iterations 2307, learning_rate 0.08173956056964066, depth 4
# 554/567, 97.71% - kfolds 10, iterations 2307, learning_rate 0.08173956056964066, depth 5
# 555/567, 97.88% - kfolds 10, iterations 2307, learning_rate 0.08173956056964066, depth 6
# 556/567, 98.06% - kfolds 10, iterations 2307, learning_rate 0.08173956056964066, depth 7
# 557/567, 98.24% - kfolds 10, iterations 2307, learning_rate 0.08173956056964066, depth 8
# 558/567, 98.41% - kfolds 10, iterations 2307, learning_rate 0.08173956056964066, depth 9
# 559/567, 98.59% - kfolds 10, iterations 2307, learning_rate 0.08173956056964066, depth 10
# 560/567, 98.77% - kfolds 10, iterations 2307, learning_rate 0.09154830783799753, depth 4
# 561/567, 98.94% - kfolds 10, iterations 2307, learning_rate 0.09154830783799753, depth 5
# 562/567, 99.12% - kfolds 10, iterations 2307, learning_rate 0.09154830783799753, depth 6
# 563/567, 99.29% - kfolds 10, iterations 2307, learning_rate 0.09154830783799753, depth 7
# 564/567, 99.47% - kfolds 10, iterations 2307, learning_rate 0.09154830783799753, depth 8
# 565/567, 99.65% - kfolds 10, iterations 2307, learning_rate 0.09154830783799753, depth 9
# 566/567, 99.82% - kfolds 10, iterations 2307, learning_rate 0.09154830783799753, depth 10
# CPU times: user 19h 56min 36s, sys: 4h 30min 44s, total: 1d 27min 20s
# Wall time: 9h 54min 9s

# %% [markdown]
# Now that the run completed, the data has been saved to "sensitivity.YYYY-mm-dd_H_M_S-PDT.txt" for more analysis and graphing. See other notebook for the graphing portion. (We want to keep this notebook for running long jobs.)

# %% [markdown]
# Quick sanity check to see the length of the results should be 567 which is the number of loops we had. And the final iteration of the loops shows that it in fact used the last element of the ranges:
#
# * iterations=2307
# * learning_rate=0.09154830783799753
# * depth=10
#
# and the resulting test set MAE for those parameters was
#
# * 59.02130682452965
#
# NOTE: for our report, the numbers will be rounded to 3 decimal places.

# %%
len(results)
# Out:
# 567

# %%
results[-1]
# Out:
# {'hyper_params': {'iterations': 2307,
#   'learning_rate': 0.09154830783799753,
#   'depth': 10,
#   'l2_leaf_reg': 0.02252067954779648,
#   'loss_function': 'MAE',
#   'random_seed': 42,
#   'verbose': False},
#  'cv_data': {'iterations': 2306.0,
#   'test-MAE-mean': 59.02130682452965,
#   'test-MAE-std': 10.864854692108924,
#   'train-MAE-mean': 0.3213471632811678,
#   'train-MAE-std': 0.07586881982866162},
#  'datetime': '2022-10-17 14:30:10 PDT'}

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6b18b33d-3a56-4f49-ad6e-71ecea9f0183' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
